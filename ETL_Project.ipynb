# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CSVs in Dataframe

# %%
people_file = "Resources/people.csv"
player_data_df = pd.read_csv(people_file)
player_data_df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile     2021.0         1.0      22.0  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
hof_file = "Resources/halloffame.csv"
hof_data_df = pd.read_csv(hof_file)
hof_data_df.head()
# Out:
#     playerID  yearID votedBy  ballots  needed  votes inducted category  \
# 0   cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1   ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2  wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3  mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4  johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
#
#   needed_note
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
awards_file = "Resources/awardsplayers.csv"
awards_data_df = pd.read_csv(awards_file)
awards_data_df.head()
# Out:
#     playerID                awardID  yearID lgID  tie notes
# 0   bondto01  Pitching Triple Crown    1877   NL  NaN   NaN
# 1  hinespa01           Triple Crown    1878   NL  NaN   NaN
# 2  heckegu01  Pitching Triple Crown    1884   AA  NaN   NaN
# 3  radboch01  Pitching Triple Crown    1884   NL  NaN   NaN
# 4  oneilti01           Triple Crown    1887   AA  NaN   NaN

# %%
pitching_file = "Resources/pitching.csv"
pitching_data_df = pd.read_csv(pitching_file)
pitching_data_df.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0  bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN   7
# 1  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN   7
# 2  fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN   2
# 3  fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN  20
# 4  fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN   0
#
#    HBP  BK     BFP  GF    R  SH  SF  GIDP
# 0  NaN   0   146.0   0   42 NaN NaN   NaN
# 1  NaN   0  1291.0   0  292 NaN NaN   NaN
# 2  NaN   0    14.0   0    9 NaN NaN   NaN
# 3  NaN   0  1080.0   1  257 NaN NaN   NaN
# 4  NaN   0    57.0   0   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
batting_file = "Resources/batting.csv"
batting_data_df = pd.read_csv(batting_file)
batting_data_df.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0  8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0  3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0  1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0  6.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
# 2  1.0   2  5.0  NaN  NaN NaN NaN   1.0
# 3  1.0   0  2.0  NaN  NaN NaN NaN   0.0
# 4  2.0   2  1.0  NaN  NaN NaN NaN   0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Create new data with select columns

# %%
new_customer_data_df = customer_data_df[['id', 'first_name', 'last_name']].copy()
new_customer_data_df.head()

# %% [markdown]
# ## Store JSON data into a DataFrame

# %%
json_file = "../Resources/hall_of_fame.json"
hall_of_fame_df = pd.read_json(json_file)
hall_of_fame_df.head()

# %% [markdown]
# ## Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
new_customer_location_df.head()

# %% [markdown]
# ## Connect to local database

# %%
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ## Check for tables

# %%
engine.table_names()

# %% [markdown]
# ## Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ## Confirm data has been added by querying the customer_name table

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()

# %% [markdown]
# ## Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
